# %%
# %reload_ext autoreload
# %autoreload 2
from data_sources.ResultsDB import ResultsDB

# %%
rdb = ResultsDB("db/historical_data.db")
rdb.load_best_results()
# Out:
# [{'model_name': 'XGBoost',
#   'target': 'point_differential',
#   'train_time_in_seconds': 0.8893909454345703,
#   'features_used': ['elo_rating',
#    'rpi_rating',
#    'days_rest',
#    'avg_point_differential_home',
#    'avg_point_differential_away',
#    'avg_turnovers_l3',
#    'avg_sack_yards_gained_home',
#    'avg_penalty_yards_home'],
#   'mean_absolute_error': 10.172194480895996,
#   'root_mean_squared_error': '13.0340617048703',
#   'train_accuracy': None,
#   'test_accuracy': None,
#   'feature_importance': {'team_a_elo_rating': 0.09511697292327881,
#    'team_b_avg_point_differential_away': 0.07895585149526596,
#    'team_b_elo_rating': 0.07596281170845032,
#    'team_b_avg_point_differential_home': 0.07459323853254318,
#    'team_a_avg_point_differential_away': 0.07158657908439636,
#    'team_a_avg_point_differential_home': 0.0659017264842987,
#    'team_b_avg_penalty_yards_home': 0.060142192989587784,
#    'team_b_avg_sack_yards_gained_home': 0.06000452861189842,
# ...
